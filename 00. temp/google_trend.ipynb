# %%
import pandas as pd
from matplotlib import pyplot as plt
import os

# %%
pd_py = pd.read_csv('py.csv', skiprows=1)
pd_ml = pd.read_csv('ml.csv', skiprows=1)
pd_py.iloc[:,1].apply(float)
pd_ml.iloc[:,1].apply(float)
# Out:
# 0      21.0
# 1      22.0
# 2      21.0
# 3      22.0
# 4      21.0
#        ...
# 256    85.0
# 257    85.0
# 258    81.0
# 259    85.0
# 260    84.0
# Name: machine learning: (全球), Length: 261, dtype: float64

# %%
pd3=pd.merge(pd_py,pd_ml, how='inner')

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
pd3.plot.line(figsize=(20, 10),lw=3, fontsize=20)
# Out:
# /Users/yukuo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 20840 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yukuo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 29699 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yukuo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 20840 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yukuo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 29699 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
pd_py.iloc[:,1]
# Out:
# 0      38
# 1      38
# 2      38
# 3      37
# 4      37
#        ..
# 256    93
# 257    92
# 258    86
# 259    93
# 260    91
# Name: python: (全球), Length: 261, dtype: int64

# %%
pd_ml.plot()
# Out:
# /Users/yukuo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 20840 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yukuo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 29699 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yukuo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 20840 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yukuo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 29699 missing from current font.
#   font.set_text(s, 0, flags=flags)
